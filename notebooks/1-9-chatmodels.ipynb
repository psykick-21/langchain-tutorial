# %% [markdown]
# # chat models

# %%
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(model="gpt-3.5-turbo-0125")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="You're a helpful assistant"),
    HumanMessage(content="What is the purpose of model regularization?"),
]

# %%
chat.invoke(messages)
# Out:
# AIMessage(content="Model regularization is a technique used in machine learning to prevent overfitting, which occurs when a model learns the training data too well and performs poorly on unseen data. Regularization introduces a penalty term to the model's loss function to discourage overly complex models that may fit the noise in the training data rather than the underlying patterns.\n\nThe purpose of model regularization is to improve the generalization of the model by reducing its complexity and increasing its ability to make accurate predictions on new, unseen data. Regularization techniques, such as L1 regularization (Lasso), L2 regularization (Ridge), and Elastic Net, help to control the model's complexity and prevent overfitting, leading to better performance and more robust models.", response_metadata={'token_usage': {'completion_tokens': 143, 'prompt_tokens': 24, 'total_tokens': 167}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a4bebad6-4764-49fa-8adc-4b0b84c34de9-0')

# %%
for chunk in chat.stream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, capturing noise and anomalies that are specific to the training data but do not generalize well to new, unseen data. Regularization techniques add a penalty term to the model's loss function, which discourages the model from becoming too complex and overfitting the training data. By imposing this penalty, regularization helps to simplify the model and improve its ability to generalize to new data, leading to better performance on unseen examples.

# %%
chat.batch([messages])
# Out:
# [AIMessage(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model performs well on the training data but poorly on new, unseen data. Regularization techniques introduce a penalty term to the model's loss function, which discourages overly complex models that may fit the noise in the training data rather than the underlying patterns. By applying regularization, models are encouraged to generalize better to new data, leading to improved performance and more reliable predictions. Common regularization techniques include L1 and L2 regularization, dropout, and early stopping.", response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 24, 'total_tokens': 136}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-05d062ab-2331-4df1-bc5a-b7af6869e8ab-0')]

# %%
await chat.ainvoke(messages)
# Out:
# AIMessage(content="Model regularization is a technique used in machine learning to prevent overfitting, which occurs when a model learns the details and noise in the training data to the extent that it negatively impacts the model's performance on unseen data. Regularization helps to generalize the model by adding a penalty term to the loss function, discouraging overly complex models that may fit the training data too closely.\n\nThe purpose of model regularization is to improve the model's ability to generalize well to unseen data, leading to better performance and more reliable predictions. By balancing the model's complexity and its fit to the training data, regularization helps to achieve a good bias-variance trade-off, reducing the risk of overfitting while maintaining model performance.", response_metadata={'token_usage': {'completion_tokens': 141, 'prompt_tokens': 24, 'total_tokens': 165}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-f328ebbf-64e7-4978-8062-42723529af4d-0')

# %%
async for chunk in chat.astream(messages):
    print(chunk.content, end="", flush=True)
# Out:
# The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, including the noise and outliers, which can result in poor generalization to new, unseen data. Regularization techniques help to constrain the model complexity and reduce overfitting by adding a penalty term to the loss function that discourages large weights or complex structures in the model. This helps the model to generalize better to new data and improve its performance on unseen examples.

# %%
async for chunk in chat.astream_log(messages):
    print(chunk)
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': 'c348f018-e1b8-4a67-9fb9-f984580dbdb8',
#             'logs': {},
#             'name': 'ChatOpenAI',
#             'streamed_output': [],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='The', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' purpose', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' of', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' model', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' regularization', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' is', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' prevent', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' over', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent over', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='fit', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfit', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ting', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' in', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' machine', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' learning', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' models', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models.', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' Over', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Over', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='fit', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfit', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ting', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' occurs', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' when', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' a', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' model', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' learns', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' training', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' too', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' well', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well,', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' point', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' that', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' it', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' performs', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' poorly', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' on', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' new', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new,', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' unseen', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data.', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' Regular', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regular', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ization', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' techniques', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' add', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' a', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' penalty', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' term', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' model', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content='The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content="'s", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' loss', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' function', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function,", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' encouraging', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' it', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' learn', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' simpler', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' patterns', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' that', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' generalize', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' better', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' new', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data.", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' By', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' incorporating', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' regularization', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=',', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization,", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' models', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' are', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' less', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' likely', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' memor', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memor", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='ize', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' noise', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' in', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' training', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' data', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' and', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' more', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' likely', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' to', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' capture', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' the', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' underlying', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' patterns', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying patterns", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' that', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying patterns that", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' are', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying patterns that are", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' truly', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying patterns that are truly", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content=' predictive', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying patterns that are truly predictive", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='.', id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying patterns that are truly predictive.", id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': AIMessageChunk(content='', response_metadata={'finish_reason': 'stop'}, id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': AIMessageChunk(content="The purpose of model regularization is to prevent overfitting in machine learning models. Overfitting occurs when a model learns the training data too well, to the point that it performs poorly on new, unseen data. Regularization techniques add a penalty term to the model's loss function, encouraging it to learn simpler patterns that generalize better to new data. By incorporating regularization, models are less likely to memorize noise in the training data and more likely to capture the underlying patterns that are truly predictive.", response_metadata={'finish_reason': 'stop'}, id='run-c348f018-e1b8-4a67-9fb9-f984580dbdb8')})

# %% [markdown]
# ### call method of chat models

# %%
from langchain_core.messages import HumanMessage, SystemMessage

chat(
    [
        HumanMessage(
            content="Translate this sentence from English to French: I love programming."
        )
    ]
)
# Out:
# /Users/psykick/Documents/learning/github/langchain-tutorial/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# AIMessage(content="J'adore la programmation.", response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 19, 'total_tokens': 27}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-5d02f403-0a25-4152-87e4-d17d9bb52044-0')

# %%
messages = [
    SystemMessage(
        content="You are a helpful assistant that translates English to French."
    ),
    HumanMessage(content="I love programming."),
]
chat(messages)
# Out:
# AIMessage(content="J'adore la programmation.", response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 26, 'total_tokens': 34}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-4e1e4382-1139-4138-a621-6d59566ec507-0')

# %% [markdown]
# ### generate method of chat models

# %%
batch_messages = [
    [
        SystemMessage(
            content="You are a helpful assistant that translates English to French."
        ),
        HumanMessage(content="I love programming."),
    ],
    [
        SystemMessage(
            content="You are a helpful assistant that translates English to French."
        ),
        HumanMessage(content="I love artificial intelligence."),
    ],
]
result = chat.generate(batch_messages)
result
# Out:
# LLMResult(generations=[[ChatGeneration(text="J'adore la programmation.", generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content="J'adore la programmation.", response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 26, 'total_tokens': 34}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-8fc7f2de-06d3-45e1-80b3-b7bebe7a9f97-0'))], [ChatGeneration(text="J'adore l'intelligence artificielle.", generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content="J'adore l'intelligence artificielle.", response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 27, 'total_tokens': 39}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-9a88616f-7dc7-45ff-a43a-48828d0d0fe1-0'))]], llm_output={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 53, 'total_tokens': 73}, 'model_name': 'gpt-3.5-turbo-0125'}, run=[RunInfo(run_id=UUID('8fc7f2de-06d3-45e1-80b3-b7bebe7a9f97')), RunInfo(run_id=UUID('9a88616f-7dc7-45ff-a43a-48828d0d0fe1'))])

# %%
result.llm_output
# Out:
# {'token_usage': {'completion_tokens': 20,
#   'prompt_tokens': 53,
#   'total_tokens': 73},
#  'model_name': 'gpt-3.5-turbo-0125'}
